# %% [markdown]
# # Mask R-CNN - Train on Shapes Dataset
#
#
# This notebook shows how to train Mask R-CNN on your own dataset. To keep things simple we use a synthetic dataset of shapes (squares, triangles, and circles) which enables fast training. You'd still need a GPU, though, because the network backbone is a Resnet101, which would be too slow to train on a CPU. On a GPU, you can start to get okay-ish results in a few minutes, and good results in less than an hour.
#
# The code of the *Shapes* dataset is included below. It generates images on the fly, so it doesn't require downloading any data. And it can generate images of any size, so we pick a small image size to train faster.

# %%
import os
import sys
import random
import math
import re
import time
import numpy as np
import cv2
import matplotlib
import matplotlib.pyplot as plt

from config import Config
import utils
import model as modellib
import visualize
from model import log

# %matplotlib inline 

# Root directory of the project
ROOT_DIR = os.getcwd()

# Directory to save logs and trained model
MODEL_DIR = os.path.join(ROOT_DIR, "logs")

# Local path to trained weights file
COCO_MODEL_PATH = os.path.join(ROOT_DIR, "mask_rcnn_coco.h5")
# Download COCO trained weights from Releases if needed
if not os.path.exists(COCO_MODEL_PATH):
    utils.download_trained_weights(COCO_MODEL_PATH)
# Out:
# c:\users\yaroslav_strontsitsk\appdata\local\continuum\anaconda3\envs\maskrcnn\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ## Configurations

# %%
class ShapesConfig(Config):
    """Configuration for training on the toy shapes dataset.
    Derives from the base Config class and overrides values specific
    to the toy shapes dataset.
    """
    # Give the configuration a recognizable name
    NAME = "shapes"

    # Train on 1 GPU and 8 images per GPU. We can put multiple images on each
    # GPU because the images are small. Batch size is 8 (GPUs * images/GPU).
    GPU_COUNT = 1
    IMAGES_PER_GPU = 8

    # Number of classes (including background)
    NUM_CLASSES = 1 + 3  # background + 3 shapes

    # Use small images for faster training. Set the limits of the small side
    # the large side, and that determines the image shape.
    IMAGE_MIN_DIM = 128
    IMAGE_MAX_DIM = 128

    # Use smaller anchors because our image and objects are small
    RPN_ANCHOR_SCALES = (8, 16, 32, 64, 128)  # anchor side in pixels

    # Reduce training ROIs per image because the images are small and have
    # few objects. Aim to allow ROI sampling to pick 33% positive ROIs.
    TRAIN_ROIS_PER_IMAGE = 32

    # Use a small epoch since the data is simple
    STEPS_PER_EPOCH = 100

    # use small validation steps since the epoch is small
    VALIDATION_STEPS = 5
    
config = ShapesConfig()
config.display()
# Out:
# Configurations:
# BACKBONE_SHAPES                [[32 32]
#  [16 16]
#  [ 8  8]
#  [ 4  4]
#  [ 2  2]]
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     8
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# GPU_COUNT                      1
# IMAGES_PER_GPU                 8
# IMAGE_MAX_DIM                  128
# IMAGE_MIN_DIM                  128
# IMAGE_PADDING                  True
# IMAGE_SHAPE                    [128 128   3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           shapes
# NUM_CLASSES                    4
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (8, 16, 32, 64, 128)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                100
# TRAIN_ROIS_PER_IMAGE           32
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               5
# WEIGHT_DECAY                   0.0001

# %% [markdown]
# ## Notebook Preferences

# %%
def get_ax(rows=1, cols=1, size=8):
    """Return a Matplotlib Axes array to be used in
    all visualizations in the notebook. Provide a
    central point to control graph sizes.
    
    Change the default size attribute to control the size
    of rendered images
    """
    _, ax = plt.subplots(rows, cols, figsize=(size*cols, size*rows))
    return ax

# %% [markdown]
# ## Dataset
#
# Create a synthetic dataset
#
# Extend the Dataset class and add a method to load the shapes dataset, `load_shapes()`, and override the following methods:
#
# * load_image()
# * load_mask()
# * image_reference()

# %%
class ShapesDataset(utils.Dataset):
    """Generates the shapes synthetic dataset. The dataset consists of simple
    shapes (triangles, squares, circles) placed randomly on a blank surface.
    The images are generated on the fly. No file access required.
    """

    def load_shapes(self, count, height, width):
        """Generate the requested number of synthetic images.
        count: number of images to generate.
        height, width: the size of the generated images.
        """
        # Add classes
        self.add_class("shapes", 1, "square")
        self.add_class("shapes", 2, "circle")
        self.add_class("shapes", 3, "triangle")

        # Add images
        # Generate random specifications of images (i.e. color and
        # list of shapes sizes and locations). This is more compact than
        # actual images. Images are generated on the fly in load_image().
        for i in range(count):
            bg_color, shapes = self.random_image(height, width)
            self.add_image("shapes", image_id=i, path=None,
                           width=width, height=height,
                           bg_color=bg_color, shapes=shapes)

    def load_image(self, image_id):
        """Generate an image from the specs of the given image ID.
        Typically this function loads the image from a file, but
        in this case it generates the image on the fly from the
        specs in image_info.
        """
        info = self.image_info[image_id]
        bg_color = np.array(info['bg_color']).reshape([1, 1, 3])
        image = np.ones([info['height'], info['width'], 3], dtype=np.uint8)
        image = image * bg_color.astype(np.uint8)
        for shape, color, dims in info['shapes']:
            image = self.draw_shape(image, shape, dims, color)
        return image

    def image_reference(self, image_id):
        """Return the shapes data of the image."""
        info = self.image_info[image_id]
        if info["source"] == "shapes":
            return info["shapes"]
        else:
            super(self.__class__).image_reference(self, image_id)

    def load_mask(self, image_id):
        """Generate instance masks for shapes of the given image ID.
        """
        info = self.image_info[image_id]
        shapes = info['shapes']
        count = len(shapes)
        mask = np.zeros([info['height'], info['width'], count], dtype=np.uint8)
        for i, (shape, _, dims) in enumerate(info['shapes']):
            mask[:, :, i:i+1] = self.draw_shape(mask[:, :, i:i+1].copy(),
                                                shape, dims, 1)
        # Handle occlusions
        occlusion = np.logical_not(mask[:, :, -1]).astype(np.uint8)
        for i in range(count-2, -1, -1):
            mask[:, :, i] = mask[:, :, i] * occlusion
            occlusion = np.logical_and(occlusion, np.logical_not(mask[:, :, i]))
        # Map class names to class IDs.
        class_ids = np.array([self.class_names.index(s[0]) for s in shapes])
        return mask, class_ids.astype(np.int32)

    def draw_shape(self, image, shape, dims, color):
        """Draws a shape from the given specs."""
        # Get the center x, y and the size s
        x, y, s = dims
        if shape == 'square':
            cv2.rectangle(image, (x-s, y-s), (x+s, y+s), color, -1)
        elif shape == "circle":
            cv2.circle(image, (x, y), s, color, -1)
        elif shape == "triangle":
            points = np.array([[(x, y-s),
                                (x-s/math.sin(math.radians(60)), y+s),
                                (x+s/math.sin(math.radians(60)), y+s),
                                ]], dtype=np.int32)
            cv2.fillPoly(image, points, color)
        return image

    def random_shape(self, height, width):
        """Generates specifications of a random shape that lies within
        the given height and width boundaries.
        Returns a tuple of three valus:
        * The shape name (square, circle, ...)
        * Shape color: a tuple of 3 values, RGB.
        * Shape dimensions: A tuple of values that define the shape size
                            and location. Differs per shape type.
        """
        # Shape
        shape = random.choice(["square", "circle", "triangle"])
        # Color
        color = tuple([random.randint(0, 255) for _ in range(3)])
        # Center x, y
        buffer = 20
        y = random.randint(buffer, height - buffer - 1)
        x = random.randint(buffer, width - buffer - 1)
        # Size
        s = random.randint(buffer, height//4)
        return shape, color, (x, y, s)

    def random_image(self, height, width):
        """Creates random specifications of an image with multiple shapes.
        Returns the background color of the image and a list of shape
        specifications that can be used to draw the image.
        """
        # Pick random background color
        bg_color = np.array([random.randint(0, 255) for _ in range(3)])
        # Generate a few random shapes and record their
        # bounding boxes
        shapes = []
        boxes = []
        N = random.randint(1, 4)
        for _ in range(N):
            shape, color, dims = self.random_shape(height, width)
            shapes.append((shape, color, dims))
            x, y, s = dims
            boxes.append([y-s, x-s, y+s, x+s])
        # Apply non-max suppression wit 0.3 threshold to avoid
        # shapes covering each other
        keep_ixs = utils.non_max_suppression(np.array(boxes), np.arange(N), 0.3)
        shapes = [s for i, s in enumerate(shapes) if i in keep_ixs]
        return bg_color, shapes

# %%
# Training dataset
dataset_train = ShapesDataset()
dataset_train.load_shapes(500, config.IMAGE_SHAPE[0], config.IMAGE_SHAPE[1])
dataset_train.prepare()

# Validation dataset
dataset_val = ShapesDataset()
dataset_val.load_shapes(50, config.IMAGE_SHAPE[0], config.IMAGE_SHAPE[1])
dataset_val.prepare()

# %%
# Load and display random samples
image_ids = np.random.choice(dataset_train.image_ids, 4)
for image_id in image_ids:
    image = dataset_train.load_image(image_id)
    mask, class_ids = dataset_train.load_mask(image_id)
    visualize.display_top_masks(image, mask, class_ids, dataset_train.class_names)

# %% [markdown]
# ## Ceate Model

# %%
# Create model in training mode
model = modellib.MaskRCNN(mode="training", config=config,
                          model_dir=MODEL_DIR)

# %%
# Which weights to start with?
init_with = "coco"  # imagenet, coco, or last

if init_with == "imagenet":
    model.load_weights(model.get_imagenet_weights(), by_name=True)
elif init_with == "coco":
    # Load weights trained on MS COCO, but skip layers that
    # are different due to the different number of classes
    # See README for instructions to download the COCO weights
    model.load_weights(COCO_MODEL_PATH, by_name=True,
                       exclude=["mrcnn_class_logits", "mrcnn_bbox_fc", 
                                "mrcnn_bbox", "mrcnn_mask"])
elif init_with == "last":
    # Load the last model you trained and continue training
    model.load_weights(model.find_last()[1], by_name=True)

# %% [markdown]
# ## Training
#
# Train in two stages:
# 1. Only the heads. Here we're freezing all the backbone layers and training only the randomly initialized layers (i.e. the ones that we didn't use pre-trained weights from MS COCO). To train only the head layers, pass `layers='heads'` to the `train()` function.
#
# 2. Fine-tune all layers. For this simple example it's not necessary, but we're including it to show the process. Simply pass `layers="all` to train all layers.

# %%
# Train the head branches
# Passing layers="heads" freezes all layers except the head
# layers. You can also pass a regular expression to select
# which layers to train by name pattern.
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE, 
            epochs=1, 
            layers='heads')
# Out:
# Starting at epoch 0. LR=0.001
#
# Checkpoint Path: D:\MaskCNN\Mask_RCNN\logs\shapes20180314T0944\mask_rcnn_shapes_{epoch:04d}.h5
# Selecting layers to train
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# WARNING:tensorflow:From D:\MaskCNN\Mask_RCNN\model.py:2073: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# (128, 128, 2)
# (128, 128, 3)
# (128, 128, 1)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 3)
# c:\users\yaroslav_strontsitsk\appdata\local\continuum\anaconda3\envs\maskrcnn\lib\site-packages\tensorflow\python\ops\gradients_impl.py:98: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Epoch 1/1
# (128, 128, 3)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 4)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 1)
#   1/100 [..............................] - ETA: 58:34 - loss: 5.9804 - rpn_class_loss: 0.0803 - rpn_bbox_loss: 2.1610 - mrcnn_class_loss: 1.7475 - mrcnn_bbox_loss: 1.4722 - mrcnn_mask_loss: 0.5195(128, 128, 3)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 3)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 3)
#   2/100 [..............................] - ETA: 51:42 - loss: 6.0984 - rpn_class_loss: 0.0756 - rpn_bbox_loss: 2.6003 - mrcnn_class_loss: 1.4349 - mrcnn_bbox_loss: 1.4539 - mrcnn_mask_loss: 0.5337(128, 128, 1)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 2)
# (128, 128, 4)
# (128, 128, 2)
#   3/100 [..............................] - ETA: 47:46 - loss: 5.5835 - rpn_class_loss: 0.0816 - rpn_bbox_loss: 2.3093 - mrcnn_class_loss: 1.1993 - mrcnn_bbox_loss: 1.4361 - mrcnn_mask_loss: 0.5572(128, 128, 1)
# (128, 128, 1)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 4)
#   4/100 [>.............................] - ETA: 46:07 - loss: 5.4859 - rpn_class_loss: 0.0869 - rpn_bbox_loss: 2.3461 - mrcnn_class_loss: 1.0542 - mrcnn_bbox_loss: 1.4319 - mrcnn_mask_loss: 0.5667(128, 128, 1)
# (128, 128, 1)
# (128, 128, 4)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 3)
#   5/100 [>.............................] - ETA: 45:04 - loss: 5.2281 - rpn_class_loss: 0.0883 - rpn_bbox_loss: 2.1604 - mrcnn_class_loss: 1.0349 - mrcnn_bbox_loss: 1.3832 - mrcnn_mask_loss: 0.5614(128, 128, 1)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 3)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 2)
#   6/100 [>.............................] - ETA: 43:48 - loss: 4.9920 - rpn_class_loss: 0.0846 - rpn_bbox_loss: 2.0237 - mrcnn_class_loss: 1.0009 - mrcnn_bbox_loss: 1.3205 - mrcnn_mask_loss: 0.5624(128, 128, 3)
# (128, 128, 3)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 3)
# (128, 128, 2)
# (128, 128, 3)
# (128, 128, 2)
#   7/100 [=>............................] - ETA: 43:05 - loss: 4.7959 - rpn_class_loss: 0.0839 - rpn_bbox_loss: 1.9485 - mrcnn_class_loss: 0.9681 - mrcnn_bbox_loss: 1.2474 - mrcnn_mask_loss: 0.5480(128, 128, 2)
# (128, 128, 2)
# (128, 128, 3)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 2)
#   8/100 [=>............................] - ETA: 42:14 - loss: 4.5839 - rpn_class_loss: 0.0813 - rpn_bbox_loss: 1.8485 - mrcnn_class_loss: 0.9278 - mrcnn_bbox_loss: 1.1923 - mrcnn_mask_loss: 0.5340(128, 128, 2)
# (128, 128, 3)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 1)
# (128, 128, 4)
#   9/100 [=>............................] - ETA: 42:01 - loss: 4.3928 - rpn_class_loss: 0.0805 - rpn_bbox_loss: 1.7518 - mrcnn_class_loss: 0.8921 - mrcnn_bbox_loss: 1.1490 - mrcnn_mask_loss: 0.5194(128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 1)
#  10/100 [==>...........................] - ETA: 41:34 - loss: 4.2191 - rpn_class_loss: 0.0796 - rpn_bbox_loss: 1.6546 - mrcnn_class_loss: 0.8640 - mrcnn_bbox_loss: 1.1063 - mrcnn_mask_loss: 0.5146(128, 128, 2)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 3)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 1)
#  11/100 [==>...........................] - ETA: 41:00 - loss: 4.1096 - rpn_class_loss: 0.0776 - rpn_bbox_loss: 1.6006 - mrcnn_class_loss: 0.8363 - mrcnn_bbox_loss: 1.0922 - mrcnn_mask_loss: 0.5029(128, 128, 2)
# (128, 128, 3)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 1)
#  12/100 [==>...........................] - ETA: 40:16 - loss: 4.0207 - rpn_class_loss: 0.0759 - rpn_bbox_loss: 1.5695 - mrcnn_class_loss: 0.8163 - mrcnn_bbox_loss: 1.0649 - mrcnn_mask_loss: 0.4940(128, 128, 4)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 3)
#  13/100 [==>...........................] - ETA: 39:49 - loss: 3.9330 - rpn_class_loss: 0.0762 - rpn_bbox_loss: 1.5360 - mrcnn_class_loss: 0.7949 - mrcnn_bbox_loss: 1.0434 - mrcnn_mask_loss: 0.4825(128, 128, 1)
# (128, 128, 3)
# (128, 128, 1)
# (128, 128, 3)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 1)
#  14/100 [===>..........................] - ETA: 39:25 - loss: 3.8386 - rpn_class_loss: 0.0745 - rpn_bbox_loss: 1.4996 - mrcnn_class_loss: 0.7746 - mrcnn_bbox_loss: 1.0163 - mrcnn_mask_loss: 0.4736(128, 128, 2)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 3)
#  15/100 [===>..........................] - ETA: 38:51 - loss: 3.7340 - rpn_class_loss: 0.0736 - rpn_bbox_loss: 1.4511 - mrcnn_class_loss: 0.7495 - mrcnn_bbox_loss: 0.9929 - mrcnn_mask_loss: 0.4670(128, 128, 2)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 4)
# (128, 128, 3)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 2)
#  16/100 [===>..........................] - ETA: 38:19 - loss: 3.6363 - rpn_class_loss: 0.0734 - rpn_bbox_loss: 1.3984 - mrcnn_class_loss: 0.7271 - mrcnn_bbox_loss: 0.9698 - mrcnn_mask_loss: 0.4677(128, 128, 2)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 3)
# (128, 128, 2)
# (128, 128, 3)
# (128, 128, 1)
# (128, 128, 1)
#  17/100 [====>.........................] - ETA: 37:44 - loss: 3.5306 - rpn_class_loss: 0.0717 - rpn_bbox_loss: 1.3452 - mrcnn_class_loss: 0.7082 - mrcnn_bbox_loss: 0.9464 - mrcnn_mask_loss: 0.4591(128, 128, 3)
# (128, 128, 1)
# (128, 128, 3)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 1)
#  18/100 [====>.........................] - ETA: 37:11 - loss: 3.4515 - rpn_class_loss: 0.0700 - rpn_bbox_loss: 1.3152 - mrcnn_class_loss: 0.6877 - mrcnn_bbox_loss: 0.9286 - mrcnn_mask_loss: 0.4500(128, 128, 1)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 4)
# (128, 128, 3)
# (128, 128, 3)
#  19/100 [====>.........................] - ETA: 36:49 - loss: 3.3805 - rpn_class_loss: 0.0697 - rpn_bbox_loss: 1.2766 - mrcnn_class_loss: 0.6745 - mrcnn_bbox_loss: 0.9096 - mrcnn_mask_loss: 0.4502(128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 3)
# (128, 128, 3)
#  20/100 [=====>........................] - ETA: 36:20 - loss: 3.3061 - rpn_class_loss: 0.0699 - rpn_bbox_loss: 1.2431 - mrcnn_class_loss: 0.6567 - mrcnn_bbox_loss: 0.8903 - mrcnn_mask_loss: 0.4461(128, 128, 1)
# (128, 128, 2)
# (128, 128, 3)
# (128, 128, 2)
# (128, 128, 3)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 2)
#  21/100 [=====>........................] - ETA: 35:46 - loss: 3.2291 - rpn_class_loss: 0.0692 - rpn_bbox_loss: 1.2066 - mrcnn_class_loss: 0.6416 - mrcnn_bbox_loss: 0.8722 - mrcnn_mask_loss: 0.4396(128, 128, 1)
# (128, 128, 3)
# (128, 128, 1)
# (128, 128, 3)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 3)
# (128, 128, 2)
#  22/100 [=====>........................] - ETA: 35:16 - loss: 3.1667 - rpn_class_loss: 0.0677 - rpn_bbox_loss: 1.1852 - mrcnn_class_loss: 0.6263 - mrcnn_bbox_loss: 0.8555 - mrcnn_mask_loss: 0.4320(128, 128, 3)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 3)
#  23/100 [=====>........................] - ETA: 34:43 - loss: 3.1081 - rpn_class_loss: 0.0666 - rpn_bbox_loss: 1.1604 - mrcnn_class_loss: 0.6132 - mrcnn_bbox_loss: 0.8429 - mrcnn_mask_loss: 0.4250(128, 128, 2)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 3)
# (128, 128, 2)
# (128, 128, 3)
# (128, 128, 2)
#  24/100 [======>.......................] - ETA: 34:08 - loss: 3.0667 - rpn_class_loss: 0.0658 - rpn_bbox_loss: 1.1394 - mrcnn_class_loss: 0.6025 - mrcnn_bbox_loss: 0.8294 - mrcnn_mask_loss: 0.4295(128, 128, 1)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 3)
# (128, 128, 1)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 2)
#  25/100 [======>.......................] - ETA: 33:35 - loss: 3.0090 - rpn_class_loss: 0.0647 - rpn_bbox_loss: 1.1207 - mrcnn_class_loss: 0.5926 - mrcnn_bbox_loss: 0.8108 - mrcnn_mask_loss: 0.4202(128, 128, 1)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 3)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 3)
# (128, 128, 1)
#  26/100 [======>.......................] - ETA: 33:05 - loss: 2.9624 - rpn_class_loss: 0.0636 - rpn_bbox_loss: 1.1046 - mrcnn_class_loss: 0.5811 - mrcnn_bbox_loss: 0.7960 - mrcnn_mask_loss: 0.4171(128, 128, 4)
# (128, 128, 3)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 1)
#  27/100 [=======>......................] - ETA: 32:34 - loss: 2.9175 - rpn_class_loss: 0.0623 - rpn_bbox_loss: 1.0890 - mrcnn_class_loss: 0.5729 - mrcnn_bbox_loss: 0.7807 - mrcnn_mask_loss: 0.4126(128, 128, 3)
# (128, 128, 1)
# (128, 128, 3)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 1)
#  28/100 [=======>......................] - ETA: 32:03 - loss: 2.8633 - rpn_class_loss: 0.0611 - rpn_bbox_loss: 1.0666 - mrcnn_class_loss: 0.5613 - mrcnn_bbox_loss: 0.7669 - mrcnn_mask_loss: 0.4075(128, 128, 1)
# (128, 128, 3)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 3)
# (128, 128, 1)
#  29/100 [=======>......................] - ETA: 31:35 - loss: 2.8181 - rpn_class_loss: 0.0600 - rpn_bbox_loss: 1.0497 - mrcnn_class_loss: 0.5530 - mrcnn_bbox_loss: 0.7526 - mrcnn_mask_loss: 0.4029(128, 128, 1)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 1)
# (128, 128, 1)
#  30/100 [========>.....................] - ETA: 31:06 - loss: 2.7667 - rpn_class_loss: 0.0587 - rpn_bbox_loss: 1.0331 - mrcnn_class_loss: 0.5419 - mrcnn_bbox_loss: 0.7364 - mrcnn_mask_loss: 0.3965(128, 128, 3)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 4)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 2)
#  31/100 [========>.....................] - ETA: 30:40 - loss: 2.7179 - rpn_class_loss: 0.0577 - rpn_bbox_loss: 1.0156 - mrcnn_class_loss: 0.5304 - mrcnn_bbox_loss: 0.7228 - mrcnn_mask_loss: 0.3914(128, 128, 1)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 2)
# (128, 128, 3)
# (128, 128, 1)
#  32/100 [========>.....................] - ETA: 30:14 - loss: 2.6795 - rpn_class_loss: 0.0568 - rpn_bbox_loss: 0.9975 - mrcnn_class_loss: 0.5211 - mrcnn_bbox_loss: 0.7119 - mrcnn_mask_loss: 0.3921(128, 128, 2)
# (128, 128, 4)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 3)
# (128, 128, 1)
#  33/100 [========>.....................] - ETA: 29:49 - loss: 2.6443 - rpn_class_loss: 0.0559 - rpn_bbox_loss: 0.9841 - mrcnn_class_loss: 0.5149 - mrcnn_bbox_loss: 0.7029 - mrcnn_mask_loss: 0.3865(128, 128, 3)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 1)
#  34/100 [=========>....................] - ETA: 29:25 - loss: 2.6065 - rpn_class_loss: 0.0550 - rpn_bbox_loss: 0.9704 - mrcnn_class_loss: 0.5088 - mrcnn_bbox_loss: 0.6922 - mrcnn_mask_loss: 0.3801(128, 128, 2)
# (128, 128, 3)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 3)
# (128, 128, 1)
# (128, 128, 1)
#  35/100 [=========>....................] - ETA: 28:57 - loss: 2.5716 - rpn_class_loss: 0.0540 - rpn_bbox_loss: 0.9571 - mrcnn_class_loss: 0.5013 - mrcnn_bbox_loss: 0.6818 - mrcnn_mask_loss: 0.3774(128, 128, 2)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 3)
# (128, 128, 2)
# (128, 128, 4)
#  36/100 [=========>....................] - ETA: 28:26 - loss: 2.5449 - rpn_class_loss: 0.0531 - rpn_bbox_loss: 0.9452 - mrcnn_class_loss: 0.4968 - mrcnn_bbox_loss: 0.6726 - mrcnn_mask_loss: 0.3772(128, 128, 1)
# (128, 128, 2)
# (128, 128, 3)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 4)
# (128, 128, 3)
# (128, 128, 3)
#  37/100 [==========>...................] - ETA: 27:58 - loss: 2.5113 - rpn_class_loss: 0.0524 - rpn_bbox_loss: 0.9328 - mrcnn_class_loss: 0.4895 - mrcnn_bbox_loss: 0.6625 - mrcnn_mask_loss: 0.3741(128, 128, 1)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 2)
#  38/100 [==========>...................] - ETA: 27:30 - loss: 2.4856 - rpn_class_loss: 0.0518 - rpn_bbox_loss: 0.9240 - mrcnn_class_loss: 0.4854 - mrcnn_bbox_loss: 0.6544 - mrcnn_mask_loss: 0.3700(128, 128, 2)
# (128, 128, 2)
# (128, 128, 4)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 2)
#  39/100 [==========>...................] - ETA: 27:02 - loss: 2.4512 - rpn_class_loss: 0.0510 - rpn_bbox_loss: 0.9105 - mrcnn_class_loss: 0.4781 - mrcnn_bbox_loss: 0.6442 - mrcnn_mask_loss: 0.3674(128, 128, 1)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 3)
# (128, 128, 3)
#  40/100 [===========>..................] - ETA: 26:35 - loss: 2.4247 - rpn_class_loss: 0.0503 - rpn_bbox_loss: 0.9011 - mrcnn_class_loss: 0.4731 - mrcnn_bbox_loss: 0.6364 - mrcnn_mask_loss: 0.3638(128, 128, 2)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 3)
# (128, 128, 2)
# (128, 128, 3)
#  41/100 [===========>..................] - ETA: 26:09 - loss: 2.4054 - rpn_class_loss: 0.0495 - rpn_bbox_loss: 0.8899 - mrcnn_class_loss: 0.4716 - mrcnn_bbox_loss: 0.6302 - mrcnn_mask_loss: 0.3643(128, 128, 2)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 3)
# (128, 128, 1)
# (128, 128, 1)
#  42/100 [===========>..................] - ETA: 25:41 - loss: 2.3816 - rpn_class_loss: 0.0487 - rpn_bbox_loss: 0.8775 - mrcnn_class_loss: 0.4669 - mrcnn_bbox_loss: 0.6233 - mrcnn_mask_loss: 0.3652(128, 128, 1)
# (128, 128, 1)
# (128, 128, 3)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 3)
# (128, 128, 4)
# (128, 128, 1)
#  43/100 [===========>..................] - ETA: 25:15 - loss: 2.3505 - rpn_class_loss: 0.0478 - rpn_bbox_loss: 0.8642 - mrcnn_class_loss: 0.4609 - mrcnn_bbox_loss: 0.6155 - mrcnn_mask_loss: 0.3621(128, 128, 4)
# (128, 128, 1)
# (128, 128, 3)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 1)
#  44/100 [============>.................] - ETA: 24:46 - loss: 2.3232 - rpn_class_loss: 0.0472 - rpn_bbox_loss: 0.8558 - mrcnn_class_loss: 0.4549 - mrcnn_bbox_loss: 0.6076 - mrcnn_mask_loss: 0.3578(128, 128, 2)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 3)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 4)
#  45/100 [============>.................] - ETA: 24:17 - loss: 2.2939 - rpn_class_loss: 0.0464 - rpn_bbox_loss: 0.8446 - mrcnn_class_loss: 0.4505 - mrcnn_bbox_loss: 0.5990 - mrcnn_mask_loss: 0.3534(128, 128, 1)
# (128, 128, 3)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 2)
# (128, 128, 2)
#  46/100 [============>.................] - ETA: 23:48 - loss: 2.2693 - rpn_class_loss: 0.0458 - rpn_bbox_loss: 0.8350 - mrcnn_class_loss: 0.4464 - mrcnn_bbox_loss: 0.5907 - mrcnn_mask_loss: 0.3513(128, 128, 2)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 3)
# (128, 128, 1)
#  47/100 [=============>................] - ETA: 23:21 - loss: 2.2559 - rpn_class_loss: 0.0452 - rpn_bbox_loss: 0.8255 - mrcnn_class_loss: 0.4435 - mrcnn_bbox_loss: 0.5841 - mrcnn_mask_loss: 0.3575(128, 128, 3)
# (128, 128, 4)
# (128, 128, 3)
# (128, 128, 1)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 1)
# (128, 128, 2)
#  48/100 [=============>................] - ETA: 22:53 - loss: 2.2387 - rpn_class_loss: 0.0447 - rpn_bbox_loss: 0.8170 - mrcnn_class_loss: 0.4399 - mrcnn_bbox_loss: 0.5799 - mrcnn_mask_loss: 0.3572(128, 128, 3)
# (128, 128, 3)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 2)
#  49/100 [=============>................] - ETA: 22:27 - loss: 2.2164 - rpn_class_loss: 0.0441 - rpn_bbox_loss: 0.8095 - mrcnn_class_loss: 0.4355 - mrcnn_bbox_loss: 0.5725 - mrcnn_mask_loss: 0.3548(128, 128, 3)
# (128, 128, 4)
# (128, 128, 4)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 3)
# (128, 128, 1)
# (128, 128, 3)
#  50/100 [==============>...............] - ETA: 21:59 - loss: 2.2094 - rpn_class_loss: 0.0436 - rpn_bbox_loss: 0.8044 - mrcnn_class_loss: 0.4358 - mrcnn_bbox_loss: 0.5700 - mrcnn_mask_loss: 0.3557(128, 128, 1)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 3)
# (128, 128, 1)
#  51/100 [==============>...............] - ETA: 21:32 - loss: 2.1882 - rpn_class_loss: 0.0430 - rpn_bbox_loss: 0.7954 - mrcnn_class_loss: 0.4326 - mrcnn_bbox_loss: 0.5640 - mrcnn_mask_loss: 0.3532(128, 128, 2)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 3)
# (128, 128, 2)
#  52/100 [==============>...............] - ETA: 21:05 - loss: 2.1734 - rpn_class_loss: 0.0425 - rpn_bbox_loss: 0.7911 - mrcnn_class_loss: 0.4298 - mrcnn_bbox_loss: 0.5582 - mrcnn_mask_loss: 0.3518(128, 128, 1)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 4)
# (128, 128, 2)
# (128, 128, 3)
# (128, 128, 1)
# (128, 128, 3)
#  53/100 [==============>...............] - ETA: 20:39 - loss: 2.1538 - rpn_class_loss: 0.0420 - rpn_bbox_loss: 0.7842 - mrcnn_class_loss: 0.4260 - mrcnn_bbox_loss: 0.5529 - mrcnn_mask_loss: 0.3487(128, 128, 1)
# (128, 128, 3)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 3)
#  54/100 [===============>..............] - ETA: 20:12 - loss: 2.1340 - rpn_class_loss: 0.0416 - rpn_bbox_loss: 0.7758 - mrcnn_class_loss: 0.4235 - mrcnn_bbox_loss: 0.5462 - mrcnn_mask_loss: 0.3470(128, 128, 1)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 2)
# (128, 128, 3)
# (128, 128, 1)
# (128, 128, 1)
#  55/100 [===============>..............] - ETA: 19:45 - loss: 2.1202 - rpn_class_loss: 0.0412 - rpn_bbox_loss: 0.7715 - mrcnn_class_loss: 0.4214 - mrcnn_bbox_loss: 0.5408 - mrcnn_mask_loss: 0.3453(128, 128, 2)
# (128, 128, 2)
# (128, 128, 4)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 3)
# (128, 128, 1)
# (128, 128, 1)
#  56/100 [===============>..............] - ETA: 19:18 - loss: 2.1029 - rpn_class_loss: 0.0407 - rpn_bbox_loss: 0.7659 - mrcnn_class_loss: 0.4183 - mrcnn_bbox_loss: 0.5354 - mrcnn_mask_loss: 0.3426(128, 128, 3)
# (128, 128, 2)
# (128, 128, 3)
# (128, 128, 4)
# (128, 128, 4)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 2)
#  57/100 [================>.............] - ETA: 18:51 - loss: 2.0907 - rpn_class_loss: 0.0402 - rpn_bbox_loss: 0.7595 - mrcnn_class_loss: 0.4161 - mrcnn_bbox_loss: 0.5302 - mrcnn_mask_loss: 0.3446(128, 128, 2)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 3)
# (128, 128, 2)
#  58/100 [================>.............] - ETA: 18:25 - loss: 2.0738 - rpn_class_loss: 0.0398 - rpn_bbox_loss: 0.7526 - mrcnn_class_loss: 0.4127 - mrcnn_bbox_loss: 0.5248 - mrcnn_mask_loss: 0.3439(128, 128, 3)
# (128, 128, 3)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 3)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 2)
#  59/100 [================>.............] - ETA: 17:58 - loss: 2.0606 - rpn_class_loss: 0.0394 - rpn_bbox_loss: 0.7485 - mrcnn_class_loss: 0.4100 - mrcnn_bbox_loss: 0.5204 - mrcnn_mask_loss: 0.3421(128, 128, 2)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 4)
# (128, 128, 1)
# (128, 128, 3)
#  60/100 [=================>............] - ETA: 17:31 - loss: 2.0486 - rpn_class_loss: 0.0390 - rpn_bbox_loss: 0.7437 - mrcnn_class_loss: 0.4088 - mrcnn_bbox_loss: 0.5161 - mrcnn_mask_loss: 0.3409(128, 128, 1)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 2)
#  61/100 [=================>............] - ETA: 17:04 - loss: 2.0354 - rpn_class_loss: 0.0386 - rpn_bbox_loss: 0.7378 - mrcnn_class_loss: 0.4073 - mrcnn_bbox_loss: 0.5114 - mrcnn_mask_loss: 0.3404(128, 128, 1)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 3)
# (128, 128, 2)
# (128, 128, 4)
#  62/100 [=================>............] - ETA: 16:36 - loss: 2.0215 - rpn_class_loss: 0.0382 - rpn_bbox_loss: 0.7326 - mrcnn_class_loss: 0.4052 - mrcnn_bbox_loss: 0.5065 - mrcnn_mask_loss: 0.3391(128, 128, 2)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 3)
# (128, 128, 1)
# (128, 128, 1)
#  63/100 [=================>............] - ETA: 16:10 - loss: 2.0062 - rpn_class_loss: 0.0378 - rpn_bbox_loss: 0.7281 - mrcnn_class_loss: 0.4017 - mrcnn_bbox_loss: 0.5021 - mrcnn_mask_loss: 0.3365(128, 128, 1)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 2)
#  64/100 [==================>...........] - ETA: 15:43 - loss: 1.9890 - rpn_class_loss: 0.0375 - rpn_bbox_loss: 0.7213 - mrcnn_class_loss: 0.3978 - mrcnn_bbox_loss: 0.4968 - mrcnn_mask_loss: 0.3356(128, 128, 1)
# (128, 128, 2)
# (128, 128, 3)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 1)
#  65/100 [==================>...........] - ETA: 15:17 - loss: 1.9726 - rpn_class_loss: 0.0372 - rpn_bbox_loss: 0.7156 - mrcnn_class_loss: 0.3937 - mrcnn_bbox_loss: 0.4916 - mrcnn_mask_loss: 0.3345(128, 128, 3)
# (128, 128, 2)
# (128, 128, 3)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 3)
# (128, 128, 1)
#  66/100 [==================>...........] - ETA: 14:52 - loss: 1.9642 - rpn_class_loss: 0.0369 - rpn_bbox_loss: 0.7123 - mrcnn_class_loss: 0.3927 - mrcnn_bbox_loss: 0.4886 - mrcnn_mask_loss: 0.3337(128, 128, 3)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 4)
# (128, 128, 3)
#  67/100 [===================>..........] - ETA: 14:27 - loss: 1.9524 - rpn_class_loss: 0.0366 - rpn_bbox_loss: 0.7080 - mrcnn_class_loss: 0.3908 - mrcnn_bbox_loss: 0.4852 - mrcnn_mask_loss: 0.3319(128, 128, 3)
# (128, 128, 3)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 4)
# (128, 128, 1)
# (128, 128, 2)
#  68/100 [===================>..........] - ETA: 14:00 - loss: 1.9420 - rpn_class_loss: 0.0364 - rpn_bbox_loss: 0.7035 - mrcnn_class_loss: 0.3884 - mrcnn_bbox_loss: 0.4814 - mrcnn_mask_loss: 0.3324(128, 128, 2)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 1)
#  69/100 [===================>..........] - ETA: 13:34 - loss: 1.9276 - rpn_class_loss: 0.0360 - rpn_bbox_loss: 0.6996 - mrcnn_class_loss: 0.3853 - mrcnn_bbox_loss: 0.4773 - mrcnn_mask_loss: 0.3294(128, 128, 3)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 1)
#  70/100 [====================>.........] - ETA: 13:08 - loss: 1.9167 - rpn_class_loss: 0.0357 - rpn_bbox_loss: 0.6948 - mrcnn_class_loss: 0.3832 - mrcnn_bbox_loss: 0.4738 - mrcnn_mask_loss: 0.3291(128, 128, 1)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 3)
#  71/100 [====================>.........] - ETA: 12:42 - loss: 1.9046 - rpn_class_loss: 0.0354 - rpn_bbox_loss: 0.6909 - mrcnn_class_loss: 0.3809 - mrcnn_bbox_loss: 0.4700 - mrcnn_mask_loss: 0.3273(128, 128, 2)
# (128, 128, 1)
# (128, 128, 3)
# (128, 128, 2)
# (128, 128, 3)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 2)
#  72/100 [====================>.........] - ETA: 12:16 - loss: 1.8930 - rpn_class_loss: 0.0351 - rpn_bbox_loss: 0.6881 - mrcnn_class_loss: 0.3785 - mrcnn_bbox_loss: 0.4664 - mrcnn_mask_loss: 0.3249(128, 128, 2)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 2)
# (128, 128, 2)
#  73/100 [====================>.........] - ETA: 11:50 - loss: 1.8809 - rpn_class_loss: 0.0348 - rpn_bbox_loss: 0.6849 - mrcnn_class_loss: 0.3761 - mrcnn_bbox_loss: 0.4631 - mrcnn_mask_loss: 0.3221(128, 128, 1)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 3)
#  74/100 [=====================>........] - ETA: 11:27 - loss: 1.8762 - rpn_class_loss: 0.0346 - rpn_bbox_loss: 0.6828 - mrcnn_class_loss: 0.3745 - mrcnn_bbox_loss: 0.4618 - mrcnn_mask_loss: 0.3225(128, 128, 4)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 3)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 3)
#  75/100 [=====================>........] - ETA: 11:01 - loss: 1.8672 - rpn_class_loss: 0.0344 - rpn_bbox_loss: 0.6787 - mrcnn_class_loss: 0.3726 - mrcnn_bbox_loss: 0.4596 - mrcnn_mask_loss: 0.3219(128, 128, 2)
# (128, 128, 3)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 3)
# (128, 128, 2)
# (128, 128, 3)
#  76/100 [=====================>........] - ETA: 10:34 - loss: 1.8572 - rpn_class_loss: 0.0342 - rpn_bbox_loss: 0.6749 - mrcnn_class_loss: 0.3704 - mrcnn_bbox_loss: 0.4564 - mrcnn_mask_loss: 0.3213(128, 128, 2)
# (128, 128, 3)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 3)
#  77/100 [======================>.......] - ETA: 10:07 - loss: 1.8463 - rpn_class_loss: 0.0340 - rpn_bbox_loss: 0.6708 - mrcnn_class_loss: 0.3680 - mrcnn_bbox_loss: 0.4534 - mrcnn_mask_loss: 0.3200(128, 128, 3)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 4)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 3)
# (128, 128, 4)
#  78/100 [======================>.......] - ETA: 9:41 - loss: 1.8394 - rpn_class_loss: 0.0338 - rpn_bbox_loss: 0.6678 - mrcnn_class_loss: 0.3668 - mrcnn_bbox_loss: 0.4508 - mrcnn_mask_loss: 0.3201 (128, 128, 1)
# (128, 128, 2)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 1)
# (128, 128, 3)
# (128, 128, 1)
#  79/100 [======================>.......] - ETA: 9:13 - loss: 1.8286 - rpn_class_loss: 0.0336 - rpn_bbox_loss: 0.6650 - mrcnn_class_loss: 0.3640 - mrcnn_bbox_loss: 0.4476 - mrcnn_mask_loss: 0.3184(128, 128, 3)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 3)
# (128, 128, 1)
#  80/100 [=======================>......] - ETA: 8:47 - loss: 1.8164 - rpn_class_loss: 0.0334 - rpn_bbox_loss: 0.6613 - mrcnn_class_loss: 0.3609 - mrcnn_bbox_loss: 0.4441 - mrcnn_mask_loss: 0.3168(128, 128, 1)
# (128, 128, 2)
# (128, 128, 3)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 4)
# (128, 128, 3)
# (128, 128, 1)
#  81/100 [=======================>......] - ETA: 8:20 - loss: 1.8057 - rpn_class_loss: 0.0332 - rpn_bbox_loss: 0.6600 - mrcnn_class_loss: 0.3574 - mrcnn_bbox_loss: 0.4406 - mrcnn_mask_loss: 0.3145(128, 128, 2)
# (128, 128, 1)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 2)
# (128, 128, 1)
#  82/100 [=======================>......] - ETA: 7:54 - loss: 1.7974 - rpn_class_loss: 0.0329 - rpn_bbox_loss: 0.6565 - mrcnn_class_loss: 0.3554 - mrcnn_bbox_loss: 0.4377 - mrcnn_mask_loss: 0.3149(128, 128, 3)
# (128, 128, 1)
# (128, 128, 4)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 3)
# (128, 128, 3)
#  83/100 [=======================>......] - ETA: 7:27 - loss: 1.7891 - rpn_class_loss: 0.0327 - rpn_bbox_loss: 0.6539 - mrcnn_class_loss: 0.3535 - mrcnn_bbox_loss: 0.4350 - mrcnn_mask_loss: 0.3139(128, 128, 2)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 1)
#  84/100 [========================>.....] - ETA: 7:01 - loss: 1.7794 - rpn_class_loss: 0.0325 - rpn_bbox_loss: 0.6510 - mrcnn_class_loss: 0.3517 - mrcnn_bbox_loss: 0.4322 - mrcnn_mask_loss: 0.3120(128, 128, 3)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 3)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 4)
#  85/100 [========================>.....] - ETA: 6:35 - loss: 1.7706 - rpn_class_loss: 0.0323 - rpn_bbox_loss: 0.6472 - mrcnn_class_loss: 0.3501 - mrcnn_bbox_loss: 0.4292 - mrcnn_mask_loss: 0.3118(128, 128, 3)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 3)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 3)
#  86/100 [========================>.....] - ETA: 6:09 - loss: 1.7636 - rpn_class_loss: 0.0321 - rpn_bbox_loss: 0.6456 - mrcnn_class_loss: 0.3485 - mrcnn_bbox_loss: 0.4262 - mrcnn_mask_loss: 0.3111(128, 128, 3)
# (128, 128, 2)
# (128, 128, 4)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 1)
#  87/100 [=========================>....] - ETA: 5:42 - loss: 1.7578 - rpn_class_loss: 0.0320 - rpn_bbox_loss: 0.6429 - mrcnn_class_loss: 0.3463 - mrcnn_bbox_loss: 0.4238 - mrcnn_mask_loss: 0.3128(128, 128, 2)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 3)
# (128, 128, 1)
#  88/100 [=========================>....] - ETA: 5:16 - loss: 1.7488 - rpn_class_loss: 0.0317 - rpn_bbox_loss: 0.6401 - mrcnn_class_loss: 0.3440 - mrcnn_bbox_loss: 0.4210 - mrcnn_mask_loss: 0.3121(128, 128, 3)
# (128, 128, 2)
# (128, 128, 4)
# (128, 128, 2)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 2)
# (128, 128, 3)
#  89/100 [=========================>....] - ETA: 4:50 - loss: 1.7399 - rpn_class_loss: 0.0316 - rpn_bbox_loss: 0.6370 - mrcnn_class_loss: 0.3421 - mrcnn_bbox_loss: 0.4184 - mrcnn_mask_loss: 0.3108(128, 128, 1)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 4)
# (128, 128, 1)
#  90/100 [==========================>...] - ETA: 4:23 - loss: 1.7314 - rpn_class_loss: 0.0314 - rpn_bbox_loss: 0.6347 - mrcnn_class_loss: 0.3397 - mrcnn_bbox_loss: 0.4156 - mrcnn_mask_loss: 0.3101(128, 128, 1)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 3)
# (128, 128, 1)
#  91/100 [==========================>...] - ETA: 3:57 - loss: 1.7239 - rpn_class_loss: 0.0311 - rpn_bbox_loss: 0.6330 - mrcnn_class_loss: 0.3377 - mrcnn_bbox_loss: 0.4134 - mrcnn_mask_loss: 0.3087(128, 128, 2)
# (128, 128, 2)
# (128, 128, 4)
# (128, 128, 3)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 1)
#  92/100 [==========================>...] - ETA: 3:31 - loss: 1.7163 - rpn_class_loss: 0.0310 - rpn_bbox_loss: 0.6310 - mrcnn_class_loss: 0.3357 - mrcnn_bbox_loss: 0.4108 - mrcnn_mask_loss: 0.3079(128, 128, 1)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 4)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 2)
#  93/100 [==========================>...] - ETA: 3:04 - loss: 1.7083 - rpn_class_loss: 0.0307 - rpn_bbox_loss: 0.6293 - mrcnn_class_loss: 0.3337 - mrcnn_bbox_loss: 0.4078 - mrcnn_mask_loss: 0.3068(128, 128, 3)
# (128, 128, 2)
# (128, 128, 3)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 3)
# (128, 128, 2)
#  94/100 [===========================>..] - ETA: 2:38 - loss: 1.7017 - rpn_class_loss: 0.0306 - rpn_bbox_loss: 0.6276 - mrcnn_class_loss: 0.3313 - mrcnn_bbox_loss: 0.4052 - mrcnn_mask_loss: 0.3071(128, 128, 4)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 4)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 3)
#  95/100 [===========================>..] - ETA: 2:11 - loss: 1.6957 - rpn_class_loss: 0.0304 - rpn_bbox_loss: 0.6253 - mrcnn_class_loss: 0.3302 - mrcnn_bbox_loss: 0.4028 - mrcnn_mask_loss: 0.3069(128, 128, 3)
# (128, 128, 2)
# (128, 128, 3)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 3)
#  96/100 [===========================>..] - ETA: 1:45 - loss: 1.6876 - rpn_class_loss: 0.0302 - rpn_bbox_loss: 0.6234 - mrcnn_class_loss: 0.3282 - mrcnn_bbox_loss: 0.4004 - mrcnn_mask_loss: 0.3053(128, 128, 1)
# (128, 128, 3)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 3)
# (128, 128, 2)
# (128, 128, 2)
# (128, 128, 1)
#  97/100 [============================>.] - ETA: 1:18 - loss: 1.6803 - rpn_class_loss: 0.0301 - rpn_bbox_loss: 0.6211 - mrcnn_class_loss: 0.3268 - mrcnn_bbox_loss: 0.3983 - mrcnn_mask_loss: 0.3040(128, 128, 1)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 1)
# (128, 128, 2)
#  98/100 [============================>.] - ETA: 52s - loss: 1.6748 - rpn_class_loss: 0.0300 - rpn_bbox_loss: 0.6192 - mrcnn_class_loss: 0.3260 - mrcnn_bbox_loss: 0.3963 - mrcnn_mask_loss: 0.3032 (128, 128, 3)
# (128, 128, 2)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 1)
# (128, 128, 1)
# (128, 128, 2)
# (128, 128, 3)
#  99/100 [============================>.] - ETA: 26s - loss: 1.6669 - rpn_class_loss: 0.0298 - rpn_bbox_loss: 0.6161 - mrcnn_class_loss: 0.3243 - mrcnn_bbox_loss: 0.3943 - mrcnn_mask_loss: 0.3025(128, 128, 2)
# (128, 128, 3)
# (128, 128, 3)
# (128, 128, 2)
# (128, 128, 3)
# (128, 128, 2)
# (128, 128, 1)
# (128, 128, 2)
# 100/100 [==============================] - 2644s 26s/step - loss: 1.6619 - rpn_class_loss: 0.0297 - rpn_bbox_loss: 0.6149 - mrcnn_class_loss: 0.3222 - mrcnn_bbox_loss: 0.3920 - mrcnn_mask_loss: 0.3031 - val_loss: 1.2037 - val_rpn_class_loss: 0.0163 - val_rpn_bbox_loss: 0.5034 - val_mrcnn_class_loss: 0.2305 - val_mrcnn_bbox_loss: 0.2401 - val_mrcnn_mask_loss: 0.2133

# %%
# Fine tune all layers
# Passing layers="all" trains all layers. You can also 
# pass a regular expression to select which layers to
# train by name pattern.
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE / 10,
            epochs=2, 
            layers="all")

# %%
# Save weights
# Typically not needed because callbacks save after every epoch
# Uncomment to save manually
# model_path = os.path.join(MODEL_DIR, "mask_rcnn_shapes.h5")
# model.keras_model.save_weights(model_path)

# %% [markdown]
# ## Detection

# %%
class InferenceConfig(ShapesConfig):
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

inference_config = InferenceConfig()

# Recreate the model in inference mode
model = modellib.MaskRCNN(mode="inference", 
                          config=inference_config,
                          model_dir=MODEL_DIR)

# Get path to saved weights
# Either set a specific path or find last trained weights
# model_path = os.path.join(ROOT_DIR, ".h5 file name here")
model_path = model.find_last()[1]

# Load trained weights (fill in path to trained weights here)
assert model_path != "", "Provide path to trained weights"
print("Loading weights from ", model_path)
model.load_weights(model_path, by_name=True)
# Out:
# Loading weights from  D:\MaskCNN\Mask_RCNN\logs\shapes20180314T0944\mask_rcnn_shapes_0001.h5

# %%
# Test on a random image
image_id = random.choice(dataset_val.image_ids)
original_image, image_meta, gt_class_id, gt_bbox, gt_mask =\
    modellib.load_image_gt(dataset_val, inference_config, 
                           image_id, use_mini_mask=False)

log("original_image", original_image)
log("image_meta", image_meta)
log("gt_class_id", gt_class_id)
log("gt_bbox", gt_bbox)
log("gt_mask", gt_mask)

visualize.display_instances(original_image, gt_bbox, gt_mask, gt_class_id, 
                            dataset_train.class_names, figsize=(8, 8))
# Out:
# LoadImageGt: Original Image Shape   (128, 128, 3)
# LoadImageGt: Original Mask Shape   (128, 128, 2)
# LoadImageGt: Resized Image Shape   (128, 128, 3)
# LoadImageGt: Resized Mask Shape   (128, 128, 2)
# original_image           shape: (128, 128, 3)         min:   14.00000  max:  206.00000
# image_meta               shape: (12,)                 min:    0.00000  max:  128.00000
# gt_class_id              shape: (2,)                  min:    3.00000  max:    3.00000
# gt_bbox                  shape: (2, 4)                min:    0.00000  max:  118.00000
# gt_mask                  shape: (128, 128, 2)         min:    0.00000  max:    1.00000
# Boxes Shape = (2, 4)
# Masks Shape = (128, 128, 2)
# ApplyMask: Image Shape   (128, 128, 3)
# ApplyMask: Mask Shape   (128, 128)
# ApplyMask: Iteration   0
# ApplyMask: Iteration   1
# ApplyMask: Iteration   2
# ApplyMask: Image Shape   (128, 128, 3)
# ApplyMask: Mask Shape   (128, 128)
# ApplyMask: Iteration   0
# ApplyMask: Iteration   1
# ApplyMask: Iteration   2

# %%
results = model.detect([original_image], verbose=1)

r = results[0]
visualize.display_instances(original_image, r['rois'], r['masks'], r['class_ids'], 
                            dataset_val.class_names, r['scores'], ax=get_ax())
# Out:
# Processing 1 images
# image                    shape: (128, 128, 3)         min:   14.00000  max:  206.00000
# molded_images            shape: (1, 128, 128, 3)      min: -102.80000  max:   82.30000
# image_metas              shape: (1, 12)               min:    0.00000  max:  128.00000
# Boxes Shape = (2, 4)
# Masks Shape = (128, 128, 2)
# ApplyMask: Image Shape   (128, 128, 3)
# ApplyMask: Mask Shape   (128, 128)
# ApplyMask: Iteration   0
# ApplyMask: Iteration   1
# ApplyMask: Iteration   2
# ApplyMask: Image Shape   (128, 128, 3)
# ApplyMask: Mask Shape   (128, 128)
# ApplyMask: Iteration   0
# ApplyMask: Iteration   1
# ApplyMask: Iteration   2

# %% [markdown]
# ## Evaluation

# %%
# Compute VOC-Style mAP @ IoU=0.5
# Running on 10 images. Increase for better accuracy.
image_ids = np.random.choice(dataset_val.image_ids, 10)
APs = []
for image_id in image_ids:
    # Load image and ground truth data
    image, image_meta, gt_class_id, gt_bbox, gt_mask =\
        modellib.load_image_gt(dataset_val, inference_config,
                               image_id, use_mini_mask=False)
    molded_images = np.expand_dims(modellib.mold_image(image, inference_config), 0)
    # Run object detection
    results = model.detect([image], verbose=0)
    r = results[0]
    # Compute AP
    AP, precisions, recalls, overlaps =\
        utils.compute_ap(gt_bbox, gt_class_id, gt_mask,
                         r["rois"], r["class_ids"], r["scores"], r['masks'])
    APs.append(AP)
    
print("mAP: ", np.mean(APs))
# Out:
# LoadImageGt: Original Image Shape   (128, 128, 3)
# LoadImageGt: Original Mask Shape   (128, 128, 3)
# LoadImageGt: Resized Image Shape   (128, 128, 3)
# LoadImageGt: Resized Mask Shape   (128, 128, 3)
# LoadImageGt: Original Image Shape   (128, 128, 3)
# LoadImageGt: Original Mask Shape   (128, 128, 2)
# LoadImageGt: Resized Image Shape   (128, 128, 3)
# LoadImageGt: Resized Mask Shape   (128, 128, 2)
# LoadImageGt: Original Image Shape   (128, 128, 3)
# LoadImageGt: Original Mask Shape   (128, 128, 2)
# LoadImageGt: Resized Image Shape   (128, 128, 3)
# LoadImageGt: Resized Mask Shape   (128, 128, 2)
# LoadImageGt: Original Image Shape   (128, 128, 3)
# LoadImageGt: Original Mask Shape   (128, 128, 2)
# LoadImageGt: Resized Image Shape   (128, 128, 3)
# LoadImageGt: Resized Mask Shape   (128, 128, 2)
# LoadImageGt: Original Image Shape   (128, 128, 3)
# LoadImageGt: Original Mask Shape   (128, 128, 2)
# LoadImageGt: Resized Image Shape   (128, 128, 3)
# LoadImageGt: Resized Mask Shape   (128, 128, 2)
# LoadImageGt: Original Image Shape   (128, 128, 3)
# LoadImageGt: Original Mask Shape   (128, 128, 2)
# LoadImageGt: Resized Image Shape   (128, 128, 3)
# LoadImageGt: Resized Mask Shape   (128, 128, 2)
# LoadImageGt: Original Image Shape   (128, 128, 3)
# LoadImageGt: Original Mask Shape   (128, 128, 2)
# LoadImageGt: Resized Image Shape   (128, 128, 3)
# LoadImageGt: Resized Mask Shape   (128, 128, 2)
# LoadImageGt: Original Image Shape   (128, 128, 3)
# LoadImageGt: Original Mask Shape   (128, 128, 1)
# LoadImageGt: Resized Image Shape   (128, 128, 3)
# LoadImageGt: Resized Mask Shape   (128, 128, 1)
# LoadImageGt: Original Image Shape   (128, 128, 3)
# LoadImageGt: Original Mask Shape   (128, 128, 2)
# LoadImageGt: Resized Image Shape   (128, 128, 3)
# LoadImageGt: Resized Mask Shape   (128, 128, 2)
# LoadImageGt: Original Image Shape   (128, 128, 3)
# LoadImageGt: Original Mask Shape   (128, 128, 4)
# LoadImageGt: Resized Image Shape   (128, 128, 3)
# LoadImageGt: Resized Mask Shape   (128, 128, 4)
# mAP:  0.5083333343267441
